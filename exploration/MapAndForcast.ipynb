# %% [markdown]
# I decided to take a look into meteostat (https://github.com/meteostat/meteostat-python) as it is the library we will use as data source for our project. First I need to install it.

# %%
pip install meteostat folium
# Out:
# Requirement already satisfied: meteostat in /usr/local/lib/python3.10/dist-packages (1.6.8)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from meteostat) (2.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from meteostat) (2024.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from meteostat) (1.26.4)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)

# %% [markdown]
# Then some basic functions from other libraries (pyplot for a simple plot, dateime for a proper date format) as well as the meteostat functions are importet

# %%
from datetime import datetime,timedelta,date
import matplotlib.pyplot as plt
from meteostat import Daily, Point, Normals, Monthly, Stations
import numpy
from geopy.distance import geodesic
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
import folium
import pandas as pd
import math

# %%
#Get the 100 closest stations to Salzburg, drop those without data and add the distance to Salzburg as additional parameter.
#This can be used for forcasting methods (as likely stations further away have less influence on the waether in Salzburg)
coord=(47.792,13.0477)
day=datetime(2024,5,20)

stations = Stations()
stations = stations.nearby(coord[0],coord[1])
stationSbg2 = stations.fetch(100)

test=stationSbg2.dropna()
indexes=test.index

for i in indexes:
  data=Daily(str(i),day-timedelta(10000),day)
  data=data.fetch()
  stat=stationSbg2.loc[str(i)]
  locatio=(stat['latitude'],stat['longitude'])
  distance=geodesic(coord,locatio).km
  #print(distance)
  data=data.assign(distance=distance)
  #print(i)
  print(data)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 1997-01-02 -10.6 -15.3  -6.9   0.0  51.0    NaN   3.0   NaN  1022.2   NaN
# 1997-01-03  -6.9  -9.4  -2.4   0.0  51.0    NaN   NaN   NaN     NaN   NaN
# 1997-01-04  -4.7 -10.8  -2.1   1.0  51.0    NaN   NaN   NaN     NaN   NaN
# 1997-01-05  -1.3  -2.9   0.3   0.0  79.0    NaN   4.2   NaN  1010.6   NaN
# 1997-01-06  -1.6  -1.8  -0.3   0.0  61.0  314.0   5.8   NaN  1017.5   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  19.2  16.7  22.3   0.0   NaN  117.0  17.7  47.0  1003.8   NaN
# 2024-05-17  13.7  11.2  16.9   3.1   NaN    2.0  11.7  38.9  1007.2   NaN
# 2024-05-18  16.0  10.1  21.9   0.9   NaN   29.0  11.1  31.3  1011.2   NaN
# 2024-05-19  16.7  11.2  22.0   1.2   NaN    6.0  11.7  55.4  1011.4   NaN
# 2024-05-20  18.2  11.8  23.9   3.0   NaN   40.0  13.1  37.1  1009.6   NaN
#
#             distance
# time
# 1997-01-02  3.682675
# 1997-01-03  3.682675
# 1997-01-04  3.682675
# 1997-01-05  3.682675
# 1997-01-06  3.682675
# ...              ...
# 2024-05-16  3.682675
# 2024-05-17  3.682675
# 2024-05-18  3.682675
# 2024-05-19  3.682675
# 2024-05-20  3.682675
#
# [10001 rows x 11 columns]
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 2002-10-15   9.5   7.1  14.0   NaN   NaN    NaN   2.9   NaN  1016.4   NaN
# 2002-10-16  10.4   6.9  17.9   NaN   NaN    NaN   3.1   NaN  1011.4   NaN
# 2002-10-17   8.3   5.4  12.3   NaN   NaN    NaN   4.9   NaN  1005.6   NaN
# 2002-10-18   6.1   1.0   8.7   NaN   NaN  229.0  12.3   NaN  1011.3   NaN
# 2002-10-19   3.5   0.4   7.6   NaN   NaN    NaN   7.1   NaN  1019.8   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  13.9  13.0  15.8   0.5   NaN   26.0  23.9  47.2  1009.0   NaN
# 2024-05-17  13.0  10.6  17.8   9.6   NaN   42.0  12.8  50.0  1007.6   NaN
# 2024-05-18  14.1   8.1  21.7   0.0   NaN   31.0   8.1  29.9  1011.7   NaN
# 2024-05-19  15.9   9.2  22.0   0.1   NaN   85.0   8.6  31.7  1011.0   NaN
# 2024-05-20  17.1  10.6  22.7   0.8   NaN   39.0  11.6  42.8  1010.2   NaN
#
#              distance
# time
# 2002-10-15  86.463514
# 2002-10-16  86.463514
# 2002-10-17  86.463514
# 2002-10-18  86.463514
# 2002-10-19  86.463514
# ...               ...
# 2024-05-16  86.463514
# 2024-05-17  86.463514
# 2024-05-18  86.463514
# 2024-05-19  86.463514
# 2024-05-20  86.463514
#
# [3791 rows x 11 columns]
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 1997-01-05  -1.7  -3.1   0.0   NaN   NaN    NaN   7.9   NaN  1010.6   NaN
# 1997-01-07  -6.6  -9.5  -5.0   NaN   NaN    NaN   9.1   NaN  1021.2   NaN
# 1997-01-08  -4.0  -6.0  -2.7   NaN   NaN    NaN   8.7   NaN  1015.8   NaN
# 1997-01-09  -4.3  -8.0  -2.0   NaN   NaN    NaN   5.5   NaN  1009.0   NaN
# 1997-01-10  -1.8  -2.5  -1.0   NaN   NaN    NaN   3.9   NaN  1016.8   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  18.0  16.2  22.2   0.0   NaN   88.0  27.6  61.0  1006.9   NaN
# 2024-05-17  14.7  11.7  17.5  11.7   NaN   18.0  15.8  54.0  1007.6   NaN
# 2024-05-18  16.3  11.2  22.7   0.9   NaN    2.0   6.9  20.5  1011.7   NaN
# 2024-05-19  17.1  11.6  22.6   4.2   NaN  334.0  11.7  47.0  1011.4   NaN
# 2024-05-20  18.8  13.5  24.2   3.7   NaN   36.0   9.6  37.1  1010.4   NaN
#
#              distance
# time
# 1997-01-05  97.905763
# 1997-01-07  97.905763
# 1997-01-08  97.905763
# 1997-01-09  97.905763
# 1997-01-10  97.905763
# ...               ...
# 2024-05-16  97.905763
# 2024-05-17  97.905763
# 2024-05-18  97.905763
# 2024-05-19  97.905763
# 2024-05-20  97.905763
#
# [8873 rows x 11 columns]
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun, distance]
# Index: []
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun  \
# time
# 1997-01-02  -8.4 -17.9  -6.0   0.0  70.0   80.0  10.8  35.3  1021.3   48.0
# 1997-01-03  -5.7  -7.7  -4.2   0.0  70.0   74.0  12.2  31.0  1011.7  180.0
# 1997-01-04  -3.6  -5.5  -2.9   0.3  70.0  208.0  12.2  34.2  1003.8    0.0
# 1997-01-05  -2.9  -6.5  -1.0   0.0  80.0  280.0   5.0  15.5  1013.3    0.0
# 1997-01-06  -3.4  -4.7  -1.9   0.0  80.0   56.0   9.7  32.8  1019.6    0.0
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 2024-05-16  17.0  10.7  23.2  11.1   0.0   78.0  13.0  48.2  1004.9  515.0
# 2024-05-17  12.6  10.2  14.6   0.1   0.0  220.0  22.0  66.6  1008.8   39.0
# 2024-05-18  15.8  10.7  21.4  14.2   0.0  236.0  14.0  46.8  1012.0  638.0
# 2024-05-19  15.7   9.4  21.0   0.0   0.0  237.0   7.9  28.8  1012.6  667.0
# 2024-05-20  16.8   7.0  23.0   0.0   0.0   88.0   8.3  25.2  1010.7  872.0
#
#               distance
# time
# 1997-01-02  112.817236
# 1997-01-03  112.817236
# 1997-01-04  112.817236
# 1997-01-05  112.817236
# 1997-01-06  112.817236
# ...                ...
# 2024-05-16  112.817236
# 2024-05-17  112.817236
# 2024-05-18  112.817236
# 2024-05-19  112.817236
# 2024-05-20  112.817236
#
# [10001 rows x 11 columns]

# %%
def nearest_station(x,y,year):
  stations = Stations()
  stations = stations.nearby(x,y)
  testi = stations.fetch()
  for i in testi.index:
      if math.isnan(Normals(i,year,year+29).fetch()['tavg'].mean())==False:
        a=i
        break
  return a

def temp_change(x,y,tstart):
  tend=tstart+29
  data3=Normals(nearest_station(x,y,tstart),tstart,tend)
  data3=data3.fetch()
  startdate=datetime.combine(date.today(), datetime.min.time())-timedelta(394)
  data4=Monthly(nearest_station(x,y,tstart),startdate,datetime.combine(date.today(), datetime.min.time())-timedelta(30))
  data4=data4.fetch()
  data5=data4['tavg'].mean()-data3['tavg'].mean()
  return data5

def gridapply(grid,tstart):
  grid['station_id']=0
  grid['tempchange']=-999
  for i in grid.index:
    grid['station_id'].iloc[i]=nearest_station(grid['latitude'].iloc[i],grid['longitude'].iloc[i],tstart)
    grid['tempchange'].iloc[i]=temp_change(grid['latitude'].iloc[i],grid['longitude'].iloc[i],tstart)
  return grid

math.isnan(Normals('65467',1961,1961+29).fetch()['tavg'].mean())
temp_change(49.6,11.0,1991)
#nearest_station(49.6,11,1961)
#Normals(nearest_station(49.6,11,1961),1961,1990).fetch()
# Out:
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# 1.1386363636363654

# %%
long=numpy.arange(-180,180,1)
long=numpy.repeat(long,len(long))
lat=numpy.arange(-180,180,1)
lat=numpy.tile(lat,len(lat))
grid=pd.DataFrame()
grid['latitude']=lat
grid['longitude']=long
grid['station_id']=0
grid['tempchange']=-999
for i in grid.index:
  grid['station_id'].iloc[i]=nearest_station(grid['latitude'].iloc[i],grid['longitude'].iloc[i],1961)
  grid['tempchange'].iloc[i]=temp_change(grid['latitude'].iloc[i],grid['longitude'].iloc[i],1961)
grid
# Out:
# FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '65380' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.19999999999999574' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d7de43306e5e> in <cell line: 10>()
#      10 for i in grid.index:
#      11   grid['station_id'].iloc[i]=nearest_station(grid['latitude'].iloc[i],grid['longitude'].iloc[i],1961)
# ---> 12   grid['tempchange'].iloc[i]=temp_change(grid['latitude'].iloc[i],grid['longitude'].iloc[i],1961)
#      13 grid
#
# <ipython-input-3-f1a32225ddb3> in temp_change(x, y, tstart)
#      11 def temp_change(x,y,tstart):
#      12   tend=tstart+29
# ---> 13   data3=Normals(nearest_station(x,y,tstart),tstart,tend)
#      14   data3=data3.fetch()
#      15   startdate=datetime.combine(date.today(), datetime.min.time())-timedelta(394)
#
# <ipython-input-3-f1a32225ddb3> in nearest_station(x, y, year)
#       1 def nearest_station(x,y,year):
#       2   stations = Stations()
# ----> 3   stations = stations.nearby(x,y)
#       4   testi = stations.fetch()
#       5   for i in testi.index:
#
# /usr/local/lib/python3.10/dist-packages/meteostat/interface/stations.py in nearby(self, lat, lon, radius)
#     126         # Sort stations by distance
#     127         temp._data.columns.str.strip()
# --> 128         temp._data = temp._data.sort_values("distance")
#     129
#     130         # Return self
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6972                 return result
#    6973
# -> 6974         new_data = self._mgr.take(
#    6975             indexer, axis=self._get_block_manager_axis(axis), verify=False
#    6976         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify)
#     874         indexer = maybe_convert_indices(indexer, n, verify=verify)
#     875
# --> 876         new_labels = self.axes[axis].take(indexer)
#     877         return self.reindex_indexer(
#     878             new_axis=new_labels,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in take(self, indices, axis, allow_fill, fill_value, **kwargs)
#    1162         else:
#    1163             # algos.take passes 'axis' keyword which not all EAs accept
# -> 1164             taken = values.take(
#    1165                 indices, allow_fill=allow_fill, fill_value=self._na_value
#    1166             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/_mixins.py in take(self, indices, allow_fill, fill_value, axis)
#     165             axis=axis,
#     166         )
# --> 167         return self._from_backing_data(new_data)
#     168
#     169     # ------------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/numpy_.py in _from_backing_data(self, arr)
#     142
#     143     def _from_backing_data(self, arr: np.ndarray) -> NumpyExtensionArray:
# --> 144         return type(self)(arr)
#     145
#     146     # ------------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/string_.py in __init__(self, values, copy)
#     350         super().__init__(values, copy=copy)
#     351         if not isinstance(values, type(self)):
# --> 352             self._validate()
#     353         NDArrayBacked.__init__(self, self._ndarray, StringDtype(storage="python"))
#     354
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/string_.py in _validate(self)
#     367             lib.convert_nans_to_NA(self._ndarray.ravel("K"))
#     368         else:
# --> 369             lib.convert_nans_to_NA(self._ndarray)
#     370
#     371     @classmethod
#
# KeyboardInterrupt:

# %%
long=numpy.arange(-180,180,1)
long=numpy.repeat(long,len(long))
lat=numpy.arange(-180,180,1)
lat=numpy.tile(lat,len(lat))
grid=pd.DataFrame()
grid['latitude']=lat
grid['longitude']=long
gridapply(grid,1961)
# Out:
# FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '65380' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.19999999999999574' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# Warning: Cannot load normals/89872.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89667.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89674.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89670.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89865.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89661.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89879.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89662.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89864.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89659.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89666.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89866.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89646.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/93498.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/93196.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/93069.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/93186.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/NFOL0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91697.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91788.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFKD0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91792.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91691.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFNB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91682.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFNW0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFVB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91676.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91669.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91659.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91784.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91663.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91665.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91657.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91670.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFSW0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91660.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91780.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91779.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFTO0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91754.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91648.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91636.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91631.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91629.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91623.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91700.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91724.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91723.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91601.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/21358.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/21937.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/L52GG.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CWWM0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/7NQ3H.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04301.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CWKU0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CP5W9.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/04310.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/04313.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01002.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/01004.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01005.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01003.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/ENHE0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01228.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01102.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01240.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01108.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01139.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/ENVR0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/01205.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/ENSF0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01300.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01210.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/ENGC0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/EGPW0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01304.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/EGPM0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals
.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68006.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68916.csv.gz from https://bulk.meteostat.net/v2/
# ...
# Warning: Cannot load normals/02259.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02376.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02443.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02458.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02460.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/02469.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02586.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/02595.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12001.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/12125.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11710.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11544.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11748.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12540.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11774.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/LZMC0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11819.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11816.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/11194.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12815.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11036.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11190.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11191.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12805.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12915.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12922.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12812.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12825.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12830.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/LHSA0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12935.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14246.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/LHPR0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12930.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12822.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12932.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14248.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14026.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14256.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14253.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14258.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14240.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/14640.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14544.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14543.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14454.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14462.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14657.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14452.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14443.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/16312.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/16318.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/16324.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/16350.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/16365.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FTTE0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/64008.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/67641.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FYGB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FYAN0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FYOT0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68714.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91293.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/PALG0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KHCA0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PAHC0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PANV0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PAIK0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02044.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01198.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02154.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02142.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02267.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02284.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02993.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02490.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/EPGI0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12135.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12345.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12435.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12530.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12455.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/11867.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/12846.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12836.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12950.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/LHTL0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12838.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/12847.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/14370.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14554.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/69171.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14382.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/13242.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/69169.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/69167.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14549.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14650.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/99912.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/69679.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/14653.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/14472.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/69731.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/14474.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/13455.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/13457.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/13461.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/13459.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/16332.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/16333.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/16685.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91736.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/64006.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/64246.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/64315.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/64328.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/67541.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/67551.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FYAB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68523.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bc9453155dce> in <cell line: 8>()
#       6 grid['latitude']=lat
#       7 grid['longitude']=long
# ----> 8 gridapply(grid,1961)
#
# <ipython-input-3-f1a32225ddb3> in gridapply(grid, tstart)
#      24   for i in grid.index:
#      25     grid['station_id'].iloc[i]=nearest_station(grid['latitude'].iloc[i],grid['longitude'].iloc[i],tstart)
# ---> 26     grid['tempchange'].iloc[i]=temp_change(grid['latitude'].iloc[i],grid['longitude'].iloc[i],tstart)
#      27   return grid
#      28
#
# <ipython-input-3-f1a32225ddb3> in temp_change(x, y, tstart)
#      14   data3=data3.fetch()
#      15   startdate=datetime.combine(date.today(), datetime.min.time())-timedelta(394)
# ---> 16   data4=Monthly(nearest_station(x,y,tstart),startdate,datetime.combine(date.today(), datetime.min.time())-timedelta(30))
#      17   data4=data4.fetch()
#      18   data5=data4['tavg'].mean()-data3['tavg'].mean()
#
# <ipython-input-3-f1a32225ddb3> in nearest_station(x, y, year)
#       4   testi = stations.fetch()
#       5   for i in testi.index:
# ----> 6       if math.isnan(Normals(i,year,year+29).fetch()['tavg'].mean())==False:
#       7         a=i
#       8         break
#
# /usr/local/lib/python3.10/dist-packages/meteostat/interface/normals.py in __init__(self, loc, start, end)
#     120         # Clear cache
#     121         if self.max_age > 0 and self.autoclean:
# --> 122             self.clear_cache()
#     123
#     124     def normalize(self):
#
# /usr/local/lib/python3.10/dist-packages/meteostat/core/cache.py in clear_cache(cls, max_age)
#      66
#      67             # Get full path
# ---> 68             path = os.path.join(cls.cache_dir + os.sep + cls.cache_subdir, file)
#      69
#      70             # Check if file is older than max_age
#
# /usr/lib/python3.10/posixpath.py in join(a, *p)
#      86                 path += b
#      87             else:
# ---> 88                 path += sep + b
#      89     except (TypeError, AttributeError, BytesWarning):
#      90         genericpath._check_arg_types('join', a, *p)
#
# KeyboardInterrupt:
