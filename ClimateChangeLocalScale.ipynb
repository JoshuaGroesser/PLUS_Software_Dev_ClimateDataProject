# %%
pip install meteostat folium
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from meteostat) (2.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from meteostat) (2024.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from meteostat) (1.26.4)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1->meteostat) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.8

# %%
from datetime import datetime,timedelta,date
import matplotlib.pyplot as plt
from meteostat import Daily, Point, Normals, Monthly, Stations
import numpy
from geopy.distance import geodesic
import folium
import pandas as pd
import math

# %% [markdown]
# Just a little code snippet to show how to extract the data from the closest 100 stations araound Salzburg, exclude those stations without information and add the distance to Salzburg to all the observations as additional variable. This can be used as a start to build a weather forcasting model.

# %%
#Get the 100 closest stations to Salzburg, drop those without data and add the distance to Salzburg as additional parameter.
#This can be used for forcasting methods (as likely stations further away have less influence on the waether in Salzburg)
coord=(47.792,13.0477)
day=datetime(2024,5,20)

stations = Stations()
stations = stations.nearby(coord[0],coord[1])
stationSbg2 = stations.fetch(100)

test=stationSbg2.dropna()
indexes=test.index

for i in indexes:
  data=Daily(str(i),day-timedelta(10000),day)
  data=data.fetch()
  stat=stationSbg2.loc[str(i)]
  locatio=(stat['latitude'],stat['longitude'])
  distance=geodesic(coord,locatio).km
  #print(distance)
  data=data.assign(distance=distance)
  #print(i)
  print(data)
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 1997-01-02 -10.6 -15.3  -6.9   0.0  51.0    NaN   3.0   NaN  1022.2   NaN
# 1997-01-03  -6.9  -9.4  -2.4   0.0  51.0    NaN   NaN   NaN     NaN   NaN
# 1997-01-04  -4.7 -10.8  -2.1   1.0  51.0    NaN   NaN   NaN     NaN   NaN
# 1997-01-05  -1.3  -2.9   0.3   0.0  79.0    NaN   4.2   NaN  1010.6   NaN
# 1997-01-06  -1.6  -1.8  -0.3   0.0  61.0  314.0   5.8   NaN  1017.5   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  19.2  16.7  22.3   0.0   NaN  117.0  17.7  47.0  1003.8   NaN
# 2024-05-17  13.7  11.2  16.9   3.1   NaN    2.0  11.7  38.9  1007.2   NaN
# 2024-05-18  16.0  10.1  21.9   0.9   NaN   29.0  11.1  31.3  1011.2   NaN
# 2024-05-19  16.7  11.2  22.0   1.2   NaN    6.0  11.7  55.4  1011.4   NaN
# 2024-05-20  18.2  11.8  23.9   3.0   NaN   40.0  13.1  37.1  1009.6   NaN
#
#             distance
# time
# 1997-01-02  3.682675
# 1997-01-03  3.682675
# 1997-01-04  3.682675
# 1997-01-05  3.682675
# 1997-01-06  3.682675
# ...              ...
# 2024-05-16  3.682675
# 2024-05-17  3.682675
# 2024-05-18  3.682675
# 2024-05-19  3.682675
# 2024-05-20  3.682675
#
# [10001 rows x 11 columns]
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 1997-07-05  13.4  11.0  15.8   NaN   NaN   32.0   6.8   NaN  1014.9   NaN
# 1997-07-06  11.1   8.5  14.7   NaN   NaN  317.0   4.5   NaN  1020.3   NaN
# 1997-07-07  10.1   8.4  12.0   NaN   NaN  314.0   6.5   NaN  1022.9   NaN
# 1997-07-08  12.3   9.2  16.6   NaN   NaN  295.0   4.8   NaN  1020.3   NaN
# 1997-07-10  15.1  10.6  20.9   NaN   NaN  267.0   5.3   NaN  1012.9   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  16.4  13.0  20.0  19.4   NaN  184.0   8.6  20.4  1004.4   NaN
# 2024-05-17  12.8   9.7  16.3  17.5   NaN  212.0   5.4  14.8  1006.8   NaN
# 2024-05-18  14.2   7.5  20.6   3.7   NaN  248.0   5.1  16.7  1011.0   NaN
# 2024-05-19  14.5   9.7  19.3   0.4   NaN  253.0   4.5  14.8  1012.0   NaN
# 2024-05-20  16.1   9.7  22.3   0.3   NaN  226.0   4.6  16.7  1009.9   NaN
#
#              distance
# time
# 1997-07-05  58.209675
# 1997-07-06  58.209675
# 1997-07-07  58.209675
# 1997-07-08  58.209675
# 1997-07-10  58.209675
# ...               ...
# 2024-05-16  58.209675
# 2024-05-17  58.209675
# 2024-05-18  58.209675
# 2024-05-19  58.209675
# 2024-05-20  58.209675
#
# [3651 rows x 11 columns]
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun  \
# time
# 1997-01-02  -8.0 -17.7  -5.3   0.0  60.0  107.0   8.6  40.0  1020.0   36.0
# 1997-01-03  -4.7  -6.4  -3.5   0.0  50.0  101.0  14.0  35.3  1009.9    0.0
# 1997-01-04  -4.2  -5.3  -1.8   0.7  50.0   90.0  11.2  36.0  1002.4    0.0
# 1997-01-05  -2.4  -5.8  -0.4   0.0  60.0  305.0   4.3  13.0  1011.6    0.0
# 1997-01-06  -2.8  -4.5   0.0   0.0  50.0   77.0   9.4  31.0  1017.9    6.0
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 2024-05-16  17.4  10.0  23.0   7.5   0.0   92.0  14.4  43.6  1004.2  502.0
# 2024-05-17  13.5  10.6  16.0   0.0   0.0  287.0  15.5  53.3  1008.1   52.0
# 2024-05-18  16.0   9.8  22.1  18.3   0.0  135.0   8.6  57.2  1011.3  513.0
# 2024-05-19  16.3  11.0  21.9   0.3   0.0   74.0   5.4  19.8  1011.7  632.0
# 2024-05-20  17.4   8.6  23.5   0.0   0.0   80.0   8.3  29.5  1009.9  790.0
#
#              distance
# time
# 1997-01-02  68.207739
# 1997-01-03  68.207739
# 1997-01-04  68.207739
# 1997-01-05  68.207739
# 1997-01-06  68.207739
# ...               ...
# 2024-05-16  68.207739
# 2024-05-17  68.207739
# 2024-05-18  68.207739
# 2024-05-19  68.207739
# 2024-05-20  68.207739
#
# [10001 rows x 11 columns]
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 2002-10-15   9.5   7.1  14.0   NaN   NaN    NaN   2.9   NaN  1016.4   NaN
# 2002-10-16  10.4   6.9  17.9   NaN   NaN    NaN   3.1   NaN  1011.4   NaN
# 2002-10-17   8.3   5.4  12.3   NaN   NaN    NaN   4.9   NaN  1005.6   NaN
# 2002-10-18   6.1   1.0   8.7   NaN   NaN  229.0  12.3   NaN  1011.3   NaN
# 2002-10-19   3.5   0.4   7.6   NaN   NaN    NaN   7.1   NaN  1019.8   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  13.9  13.0  15.8   0.5   NaN   26.0  23.9  47.2  1009.0   NaN
# 2024-05-17  13.0  10.6  17.8   9.6   NaN   42.0  12.8  50.0  1007.6   NaN
# 2024-05-18  14.1   8.1  21.7   0.0   NaN   31.0   8.1  29.9  1011.7   NaN
# 2024-05-19  15.9   9.2  22.0   0.1   NaN   85.0   8.6  31.7  1011.0   NaN
# 2024-05-20  17.1  10.6  22.7   0.8   NaN   39.0  11.6  42.8  1010.2   NaN
#
#              distance
# time
# 2002-10-15  86.463514
# 2002-10-16  86.463514
# 2002-10-17  86.463514
# 2002-10-18  86.463514
# 2002-10-19  86.463514
# ...               ...
# 2024-05-16  86.463514
# 2024-05-17  86.463514
# 2024-05-18  86.463514
# 2024-05-19  86.463514
# 2024-05-20  86.463514
#
# [3791 rows x 11 columns]
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 1997-01-05  -1.7  -3.1   0.0   NaN   NaN    NaN   7.9   NaN  1010.6   NaN
# 1997-01-07  -6.6  -9.5  -5.0   NaN   NaN    NaN   9.1   NaN  1021.2   NaN
# 1997-01-08  -4.0  -6.0  -2.7   NaN   NaN    NaN   8.7   NaN  1015.8   NaN
# 1997-01-09  -4.3  -8.0  -2.0   NaN   NaN    NaN   5.5   NaN  1009.0   NaN
# 1997-01-10  -1.8  -2.5  -1.0   NaN   NaN    NaN   3.9   NaN  1016.8   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-05-16  18.0  16.2  22.2   0.0   NaN   88.0  27.6  61.0  1006.9   NaN
# 2024-05-17  14.7  11.7  17.5  11.7   NaN   18.0  15.8  54.0  1007.6   NaN
# 2024-05-18  16.3  11.2  22.7   0.9   NaN    2.0   6.9  20.5  1011.7   NaN
# 2024-05-19  17.1  11.6  22.6   4.2   NaN  334.0  11.7  47.0  1011.4   NaN
# 2024-05-20  18.8  13.5  24.2   3.7   NaN   36.0   9.6  37.1  1010.4   NaN
#
#              distance
# time
# 1997-01-05  97.905763
# 1997-01-07  97.905763
# 1997-01-08  97.905763
# 1997-01-09  97.905763
# 1997-01-10  97.905763
# ...               ...
# 2024-05-16  97.905763
# 2024-05-17  97.905763
# 2024-05-18  97.905763
# 2024-05-19  97.905763
# 2024-05-20  97.905763
#
# [8873 rows x 11 columns]
# Empty DataFrame
# Columns: [tavg, tmin, tmax, prcp, snow, wdir, wspd, wpgt, pres, tsun, distance]
# Index: []
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun  \
# time
# 1997-01-02  -8.4 -17.9  -6.0   0.0  70.0   80.0  10.8  35.3  1021.3   48.0
# 1997-01-03  -5.7  -7.7  -4.2   0.0  70.0   74.0  12.2  31.0  1011.7  180.0
# 1997-01-04  -3.6  -5.5  -2.9   0.3  70.0  208.0  12.2  34.2  1003.8    0.0
# 1997-01-05  -2.9  -6.5  -1.0   0.0  80.0  280.0   5.0  15.5  1013.3    0.0
# 1997-01-06  -3.4  -4.7  -1.9   0.0  80.0   56.0   9.7  32.8  1019.6    0.0
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 2024-05-16  17.0  10.7  23.2  11.1   0.0   78.0  13.0  48.2  1004.9  515.0
# 2024-05-17  12.6  10.2  14.6   0.1   0.0  220.0  22.0  66.6  1008.8   39.0
# 2024-05-18  15.8  10.7  21.4  14.2   0.0  236.0  14.0  46.8  1012.0  638.0
# 2024-05-19  15.7   9.4  21.0   0.0   0.0  237.0   7.9  28.8  1012.6  667.0
# 2024-05-20  16.8   7.0  23.0   0.0   0.0   88.0   8.3  25.2  1010.7  872.0
#
#               distance
# time
# 1997-01-02  112.817236
# 1997-01-03  112.817236
# 1997-01-04  112.817236
# 1997-01-05  112.817236
# 1997-01-06  112.817236
# ...                ...
# 2024-05-16  112.817236
# 2024-05-17  112.817236
# 2024-05-18  112.817236
# 2024-05-19  112.817236
# 2024-05-20  112.817236
#
# [10001 rows x 11 columns]

# %% [markdown]
# We want to analyse climate change on a local scale, so that people can see how climate change affected different areas. Therefore, we need a function that shows for any given reference period and spatial input data by how much the past year differed from the reference period in that area. Therefore, we hand over a grid that consists of real-world coordinates and the start of a reference period. Then, for every point in the grid we look for the closest station that has climate normals data starting in the given year. This climate normals data is our reference of how warm it used to be (on average) in that location. Then we compare the temperature in the past year with the temperature in the reference period.
#
# So we get a data frame that stores for any geographic location by how much the average temperature in the past year differed from the normal temperature in the reference period.
#
# Climate normals take into account a period of 30 years, which is the period suggested by the World Meteorological Organization. Thus it makes sense to stick to this definition, not only for convenience as we can use the function built into meteostat, but also for scientific consistency.
#
# This data could then be used for further analysis or to create some kind of weather map, visualising climate change on a local scale.

# %%
#First, we finde the closest station to given coordinates for that climate normals are available for the given time period.
#x,y are latitude and longitude coordinates (e.g 8.753), year is the start of the reference period (e.g. 1961)
def nearest_station(x,y,year):
  stations = Stations()
  stations = stations.nearby(x,y)
  testi = stations.fetch() #all the stations ordered by how close they are to the given coordiantes
  for i in testi.index:
      if math.isnan(Normals(i,year,year+29).fetch()['tavg'].mean())==False: #check if there is a mean temperature of the average temperature in the climate normals. This serves as a not-yet perfect but still okayish condition for the data to be available
        a=i #if this station has climate normals for the given period, store it
        break #we found the closest station satisfying the condition, end search
  return a #id of the station is the output

#Then, we check by how far the temperature changed at a given location  compared to a reference period.
def temp_change(x,y,tstart):
  tend=tstart+29 #reference period has a length of 30 years
  data3=Normals(nearest_station(x,y,tstart),tstart,tend).fetch() #get the climate normals from the closest station to the location
  #we compare this with the past year, starting one month before today. On the one hand, this gives us very recent data, on the other hand it increaes the possibility that the data is already available.
  startdate=datetime.combine(date.today(), datetime.min.time())-timedelta(394) #bring the times in the right format for the functions to work
  data4=Monthly(nearest_station(x,y,tstart),startdate,datetime.combine(date.today(), datetime.min.time())-timedelta(30)).fetch() #Get the data from the past year
  data5=data4['tavg'].mean()-data3['tavg'].mean() #difference of mean tmeperature from reference period and the past year. 'tavg' averages over the days, mean() averages over the months
  return data5

#We combine this together. grid has to be some data frame, containing geographic coordinates, tstart is the starting year of the reference period
def gridapply(grid,tstart):
  grid['station_id']=0 #initialise the id of the closest station
  grid['tempchange']=-999 #initialise the temperature change. Value chosen such that algorithmic errors not producing tempchanges are easily found
  for i in grid.index: #for every location in the grid
    grid['station_id'].iloc[i]=nearest_station(grid['longitude'].iloc[i],grid['latitude'].iloc[i],tstart) #find the nearest station having the desired climate normals
    grid['tempchange'].iloc[i]=temp_change(grid['longitude'].iloc[i],grid['latitude'].iloc[i],tstart) #calculate the temperature change of interest
  return grid

# %% [markdown]
# Now we want to test our function. Therefore, we create a grid that is spanned over the world in steps of 20 degree (both longitude and latitude). We then check for every point how the temperature has changed compared to 1961-1990.
#
# Some of the points share the closest station and thus the temperature changes. This is due to the distribution of the stations (especially on the oceans, ehere are none to almost none). So we must take the results with a grain of salt in those cases. However, wherever the nearest station is close to the location, we get useful results.

# %%
long=numpy.arange(-180,180,20)
long=numpy.repeat(long,len(long))
lat=numpy.arange(-180,180,20)
lat=numpy.tile(lat,len(lat)) #By using tile and repeat we ensure that the grid long x lat contains all possible combinations and thus is really the desired grid
grid=pd.DataFrame()
grid['latitude']=lat
grid['longitude']=long
gridapply(grid,1961)
# Out:
# Warning: Cannot load normals/65469.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65465.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65473.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65475.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65457.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65459.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65460.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65462.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65453.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65445.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/40569.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/65450.csv.gz from https://bulk.meteostat.net/v2/
# FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '65380' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.19999999999999574' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# Warning: Cannot load normals/64008.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/64006.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/64108.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/HKMK0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63695.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63772.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/HKIS0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63270.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63720.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63694.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63717.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63641.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/63766.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/97580.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/97698.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91355.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91350.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91530.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/ANYN0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91629.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91623.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91631.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91636.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91601.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91700.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91648.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/76723.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/84001.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/84010.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/81699.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/81700.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/82294.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/81755.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/82288.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/81752.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/82392.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/81717.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/81754.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/FYTK0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FYTM0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/67285.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/67131.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/YCCY0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91574.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91570.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91573.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91697.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFOL0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFKD0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91691.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFNW0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFNB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFVB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91676.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91682.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91669.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91663.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91659.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91665.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91657.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFSW0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91660.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91670.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91788.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91792.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91784.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91780.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91779.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91754.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NFTO0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91831.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NCAT0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NCMR0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91840.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NCMG0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NCSW0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91822.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NCMH0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NCNS0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91804.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/NTGJ0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/NTGA0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91961.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/91964.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/84720.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/83554.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86767.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86833.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SGPG0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86768.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86807.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/85312.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SLAG0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SLTI0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86808.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SLVG0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SGPJ0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/83649.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86830.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/FAOB0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FABR0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68916.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68928.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/95997.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/94997.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/YMTG0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/93800.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/93709.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/93805.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/93830.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/93831.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/85818.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SCJO0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/86998.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/83970.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/86994.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/68902.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/68992.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89514.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89532.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89570.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89811.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89809.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89642.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89832.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89834.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89646.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89648.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89615.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89879.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89661.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89327.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89324.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89062.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/85972.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89083.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89065.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89061.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/85921.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/85967.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SCFM0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/SCRM0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89058.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89251.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89013.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89507.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89022.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89016.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89504.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89734.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89003.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89108.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89744.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89799.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89577.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89578.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89767.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89625.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89828.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89869.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89873.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89868.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89668.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89768.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89866.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89667.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89769.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89669.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89670.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/89674.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89376.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89872.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89377.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89345.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89332.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89329.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89087.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89272.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89257.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89314.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/89266.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/76625.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/MWCB0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/78861.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/78862.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/TQPF0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/78858.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/78859.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/78873.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/TRPG0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/GVSV0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/08583.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/08589.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/GVNP0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/GVBA0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/DAAT0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/91736.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/FTTZ0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/41020.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/41026.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/42946.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43029.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42866.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42953.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43025.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42948.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42871.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42939.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42876.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42943.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42872.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42874.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43087.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42715.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42771.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43081.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43019.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42937.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42768.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43136.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43083.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42776.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43021.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42860.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42935.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43137.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43097.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42934.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42767.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43042.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42770.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43133.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42961.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43125.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43017.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOHS0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43182.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42783.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42779.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43076.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VORY0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42763.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43177.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43181.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42931.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43147.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42679.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42884.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43168.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VEVZ0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOVZ0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42855.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42674.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42672.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43187.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43012.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42883.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43121.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42669.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43220.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43011.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42792.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43105.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42886.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42851.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42693.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43013.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42849.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43221.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43169.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43213.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42571.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43049.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42574.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42577.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43212.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42665.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42969.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43071.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42562.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42567.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43009.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42557.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42662.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42793.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42752.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42467.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43243.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42925.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43161.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43160.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42559.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42891.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43069.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43053.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42473.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42463.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43241.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42661.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43205.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42920.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42555.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42459.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOJV0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42460.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42921.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43064.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43228.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42701.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42469.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42471.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42483.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42795.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42468.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43158.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42751.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42479.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42700.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43113.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43201.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42588.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42976.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42482.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43111.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43275.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42973.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42699.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42372.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43061.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOTP0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43157.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42799.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42798.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42367.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43060.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42456.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42366.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42547.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42375.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43200.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42591.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42894.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43271.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43264.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42915.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42895.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42748.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42747.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42916.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VADN0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43230.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42450.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43002.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42840.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43227.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42705.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43001.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42453.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43277.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43058.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43109.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VASU0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42368.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43278.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42354.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42546.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43110.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43272.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42744.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43303.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOBL0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42803.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43299.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42488.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43153.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42265.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42447.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VAUD0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42349.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42542.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42706.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43193.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42274.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43258.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42271.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43296.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42543.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42379.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42900.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43194.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43196.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42838.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42901.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42654.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43005.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOND0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43302.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43225.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42273.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42704.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42837.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42977.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43226.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42805.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42387.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43260.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42266.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43229.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43263.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42270.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43259.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42811.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42709.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42708.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43257.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/VOPC0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43331.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42383.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42282.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42262.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43301.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/43289.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42255.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42343.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/44438.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42540.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/42441.csv.gz from https://bulk.meteostat.net/v2/
# ...
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/70482.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/70489.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/DCEJ7.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PAKF0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PAVC0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PASD0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/2CZLJ.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KBOK0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KCEC0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/KRTS0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/KNRN0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KOIN0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KHLC0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KHDE0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KLXN0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KADT0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KCZD0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KK820.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KCBK0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KEAR0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KOEL0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/KAFJ0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/KVVS0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/F2UX6.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/08502.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/08505.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CWQJ0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/13625.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/UTNU0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/51730.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/PAQH0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PATG0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PFKW0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/71247.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/PEQ98.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/C1ZOZ.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/025P3.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CYBQ0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/71507.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/6ODMU.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/K8CJD.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/71812.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/6HZ9U.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/Q94L8.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/CYKO0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CYPX0.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/71176.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/71804.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/71098.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/04382.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04285.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04272.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04261.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04266.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04373.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/BGPT0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04260.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04253.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/02980.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02970.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02741.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02493.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02790.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02993.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02979.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/02490.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/27026.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/21358.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/71072.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CWCN0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/L52GG.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/5M70U.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/9L8V7.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/CP5W9.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/7NQ3H.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CWWM0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/CWKU0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04205.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/04301.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04310.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/04313.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/01004.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# Warning: Cannot load normals/01002.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load normals/01024.csv.gz from https://bulk.meteostat.net/v2/
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#      latitude  longitude station_id  tempchange
# 0        -180       -180      65380    0.200000
# 1        -160       -180      64458    0.750000
# 2        -140       -180      63740    1.000000
# 3        -120       -180      63980    0.812821
# 4        -100       -180      43497    0.150000
# ..        ...        ...        ...         ...
# 319        80        160      76675    2.700000
# 320       100        160      78384    2.535256
# 321       120        160      78897    0.137179
# 322       140        160      81405   -0.642308
# 323       160        160      61415    3.916667
#
# [324 rows x 4 columns]
